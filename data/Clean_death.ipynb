# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/prakb/OneDrive/Desktop/Heartthrob/data/NCHS_-_Leading_Causes_of_Death__United_States.csv")

# %%
df['Year'] = df['Year'].astype(str)

# %%
df
# Out:
#        Year                                     113 Cause Name  \
# 0      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2017  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10863  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10864  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10865  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10866  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 10867  1999  Nephritis, nephrotic syndrome and nephrosis (N...
#
#                    Cause Name          State   Deaths Age-adjusted Death Rate
# 0      Unintentional injuries  United States  169,936                    49.4
# ...

# %%
filtered_df = df.loc[(df['Year'] >= '2012')
                     & (df['Year'] <= '2017')]

# %%
filtered_df
# Out:
#       Year                                     113 Cause Name  \
# 0     2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1     2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2     2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3     2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4     2017  Accidents (unintentional injuries) (V01-X59,Y8...
# ...    ...                                                ...
# 3431  2012  Nephritis, nephrotic syndrome and nephrosis (N...
# 3432  2012  Nephritis, nephrotic syndrome and nephrosis (N...
# 3433  2012  Nephritis, nephrotic syndrome and nephrosis (N...
# 3434  2012  Nephritis, nephrotic syndrome and nephrosis (N...
# 3435  2012  Nephritis, nephrotic syndrome and nephrosis (N...
#
#                   Cause Name          State   Deaths Age-adjusted Death Rate
# 0     Unintentional injuries  United States  169,936                    49.4
# ...

# %%
filtered_df1 =filtered_df.loc[df['113 Cause Name'].str.contains("All Causes", case=False)]
filtered_df1
# Out:
#       Year 113 Cause Name  Cause Name          State     Deaths  \
# 52    2017     All Causes  All causes  United States  2,813,503
# 53    2017     All Causes  All causes        Alabama     53,238
# 54    2017     All Causes  All causes         Alaska      4,411
# 55    2017     All Causes  All causes        Arizona     57,758
# 56    2017     All Causes  All causes       Arkansas     32,588
# ...    ...            ...         ...            ...        ...
# 2963  2012     All Causes  All causes       Virginia     61,564
# 2964  2012     All Causes  All causes     Washington     50,105
# 2965  2012     All Causes  All causes  West Virginia     21,915
# 2966  2012     All Causes  All causes      Wisconsin     48,384
# 2967  2012     All Causes  All causes        Wyoming      4,481
#
#      Age-adjusted Death Rate
# 52                     731.9
# 53                     917.7
# 54                     708.8
# 55                     678.5
# 56                     900.1
# ...

# %%
filtered_df1.to_csv("filtered.csv",
                  encoding="utf-8",index=False, header=True)

# %%
# Out:
# Empty DataFrame
# Columns: [Year, 113 Cause Name, Cause Name, State, Deaths, Age-adjusted Death Rate]
# Index: []
