# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/prakb/OneDrive/Desktop/Income per Capita.csv")

# %%
df.columns = df.iloc[0]

# %%
df
# Out:
# 0                  State      2012      2013      2014      2015      2016  \
# 0                  State      2012      2013      2014      2015      2016
# 1                Alabama   35,824    36,014    37,055    38,531    39,014
# 2                 Alaska   53,708    52,812    55,867    57,575    56,278
# 3                Arizona   36,545    37,139    38,756    40,334    41,473
# 4               Arkansas   36,582    36,677    38,749    39,968    40,873
# 5             California   48,121    48,502    51,266    54,546    56,560
# 6               Colorado   45,630    47,404    50,797    52,339    52,390
# 7            Connecticut   64,121    62,647    65,498    67,321    68,680
# 8               Delaware   44,070    44,404    46,015    47,868    48,734
# 9   District of Columbia   68,148    67,774    71,469    75,623    78,186
# 10               Florida   41,540    41,162    43,516    45,659    46,454
# 11               Georgia   37,495    37,794    39,969    41,941    43,033
# ...

# %%
del df["2018"]

# %%
del df["https://fred.stlouisfed.org/series/ALPCPI"]

# %%
# Out:
# Empty DataFrame
# Columns: [State, 2012, 2013, 2014, 2015, 2016, 2017, nan, nan, nan]
# Index: []

# %%
df
# Out:
# 0                  State      2012      2013      2014      2015      2016  \
# 0                  State      2012      2013      2014      2015      2016
# 1                Alabama   35,824    36,014    37,055    38,531    39,014
# 2                 Alaska   53,708    52,812    55,867    57,575    56,278
# 3                Arizona   36,545    37,139    38,756    40,334    41,473
# 4               Arkansas   36,582    36,677    38,749    39,968    40,873
# 5             California   48,121    48,502    51,266    54,546    56,560
# 6               Colorado   45,630    47,404    50,797    52,339    52,390
# 7            Connecticut   64,121    62,647    65,498    67,321    68,680
# 8               Delaware   44,070    44,404    46,015    47,868    48,734
# 9   District of Columbia   68,148    67,774    71,469    75,623    78,186
# 10               Florida   41,540    41,162    43,516    45,659    46,454
# 11               Georgia   37,495    37,794    39,969    41,941    43,033
# ...

# %%
df.to_csv("income.csv",
                  encoding="utf-8",index=False, header=True)
